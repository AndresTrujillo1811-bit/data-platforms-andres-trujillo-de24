# %% [markdown]
# # Plotting basics
#
# - matplotlib
# - seaborn
# - pandas plot() method

# %%
import pandas as pd 

df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/refs/heads/master/titanic.csv")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %%
df["age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.hist(df["age"])
plt.xlabel("age")
plt.ylabel("count")
plt.title("Histogram of ages in titanic dataset")
# Out:
# Text(0.5, 1.0, 'Histogram of ages in titanic dataset')

# %%
# OOP approach in matplotlib

fig, ax = plt.subplots(1)
ax.hist(df["age"], bins=50)
ax.set(title="Histogram of ages in titanic dataset", xlabel="age", ylabel="count")
# Out:
# [Text(0.5, 1.0, 'Histogram of ages in titanic dataset'),
#  Text(0.5, 0, 'age'),
#  Text(0, 0.5, 'count')]

# %%
# bar chart in matplotlib

df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
classes = df["class"].value_counts().reset_index()
classes
# Out:
#     class  count
# 0   Third    491
# 1   First    216
# 2  Second    184

# %%
fig, ax = plt.subplots(1)
ax.bar(x = classes["class"], height = classes["count"])
ax.set(xlabel = "class", ylabel="count", title = "Classes onboard of titanic")
# Out:
# [Text(0.5, 0, 'class'),
#  Text(0, 0.5, 'count'),
#  Text(0.5, 1.0, 'Classes onboard of titanic')]

# %%
cohorts = ["DE23", "DE24", "AI23", "JAVA24"], "Matematik"
number_students = [29, 38, 28, 20]

fig, ax = plt.subplots(1)
ax.bar(x=cohorts, height=number_students)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       2 number_students = [29, 38, 28, 20]
#       4 fig, ax = plt.subplots(1)
# ----> 5 ax.bar(x=cohorts, height=number_students)
#
# File c:\Users\andre\Documents\github\data-platforms-andres-trujillo-de24\.venv\Lib\site-packages\matplotlib\__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File c:\Users\andre\Documents\github\data-platforms-andres-trujillo-de24\.venv\Lib\site-packages\matplotlib\axes\_axes.py:2544, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2538         x = 0
#    2540 if orientation == 'vertical':
#    2541     # It is possible for y (bottom) to contain unit information.
#    2542     # However, it is also possible for y=0 for the default and height
#    2543     # to contain unit information.  This will prioritize the units of y.
# -> 2544     self._process_unit_info(
#    2545         [("x", x), ("y", y), ("y", height)], kwargs, convert=False)
#    2546     if log:
#    2547         self.set_yscale('log', nonpositive='clip')
#
# File c:\Users\andre\Documents\github\data-platforms-andres-trujillo-de24\.venv\Lib\site-packages\matplotlib\axes\_base.py:2617, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2615     # Update from data if axis is already set but no unit is set yet.
#    2616     if axis is not None and data is not None and not axis.have_units():
# -> 2617         axis.update_units(data)
#    2618 for axis_name, axis in axis_map.items():
#    2619     # Return if no axis is set.
#    2620     if axis is None:
#
# File c:\Users\andre\Documents\github\data-platforms-andres-trujillo-de24\.venv\Lib\site-packages\matplotlib\axis.py:1765, in Axis.update_units(self, data)
#    1763 neednew = self._converter != converter
#    1764 self._set_converter(converter)
# -> 1765 default = self._converter.default_units(data, self)
#    1766 if default is not None and self.units is None:
#    1767     self.set_units(default)
#
# File c:\Users\andre\Documents\github\data-platforms-andres-trujillo-de24\.venv\Lib\site-packages\matplotlib\category.py:106, in StrCategoryConverter.default_units(data, axis)
#     104 # the conversion call stack is default_units -> axis_info -> convert
#     105 if axis.units is None:
# --> 106     axis.set_units(UnitData(data))
#     107 else:
#     108     axis.units.update(data)
#
# File c:\Users\andre\Documents\github\data-platforms-andres-trujillo-de24\.venv\Lib\site-packages\matplotlib\category.py:182, in UnitData.__init__(self, data)
#     180 self._counter = itertools.count()
#     181 if data is not None:
# --> 182     self.update(data)
#
# File c:\Users\andre\Documents\github\data-platforms-andres-trujillo-de24\.venv\Lib\site-packages\matplotlib\category.py:215, in UnitData.update(self, data)
#     213 # check if convertible to number:
#     214 convertible = True
# --> 215 for val in OrderedDict.fromkeys(data):
#     216     # OrderedDict just iterates over unique values in data.
#     217     _api.check_isinstance((str, bytes), value=val)
#     218     if convertible:
#     219         # this will only be called so long as convertible is True.
#
# TypeError: unhashable type: 'list'

# %%
#bar chart in seaborn

import seaborn as sns 

classes
# Out:
#     class  count
# 0   Third    491
# 1   First    216
# 2  Second    184

# %%
# matplotlib 
# fig, ax = plt.subplots(1)
# ax.bar(x = classes["class"], height = classes["count"])
# ax.set(xlabel = "class", ylabel="count", title = "Classes onboard of titanic")

# seaborn
ax = sns.barplot(classes, x = "class", y="count" )
ax.set(title = "Classes onboard of titanic")

# %%
sns.histplot(df, x="age", hue="sex", multiple="dodge", kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
# pandas plot method

ax = classes.plot(kind = "bar")
ax
# Out:
# <Axes: >
